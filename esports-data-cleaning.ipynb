# %%
import pandas as pd
import numpy as np
from dateutil.parser import parse

# %%
df_raw = pd.read_csv('./esports-starcraft2-data.csv')

# %%
df_raw.columns
# Out:
# Index(['replay_id', 'scraped_from_site', 'player_1_name', 'player_1_species',
#        'player_1_build_order_names', 'player_1_build_order',
#        'player_1_salt_encoding', 'player_1_winner_status',
#        'player_1_spawn_location', 'player_1_league', 'player_2_name',
#        'player_2_species', 'player_2_build_order_names',
#        'player_2_build_order', 'player_2_salt_encoding',
#        'player_2_winner_status', 'player_2_spawn_location', 'player_2_league',
#        'tags', 'map', 'played_on_date_and_time', 'game_length',
#        'tournament_name', 'other_games_in_series',
#        'other_games_in_series_addresses', 'replay_download_address',
#        'vod_address', 'replay_description', 'data_creation_datetime'],
#       dtype='object')

# %%
df_cleaned = df_raw.drop(['replay_id', 'scraped_from_site', 
             'player_1_build_order', 'player_1_salt_encoding', 'player_1_spawn_location',
             'player_2_build_order', 'player_2_salt_encoding', 'player_2_spawn_location',
             'tags',
             'other_games_in_series', 'other_games_in_series_addresses',
             'replay_download_address', 'vod_address', 'replay_description',
             'data_creation_datetime'], axis = 1)

# %%
df_cleaned.head()
# Out:
#   player_1_name player_1_species      player_1_build_order_names  \
# 0    Replicant            Terran                 Cyclone Opening
# 1       Spirit            Terran  Cyclone Opening, Reaper Expand
# 2      Classic           Protoss   1 Gate Expand, Oracle Opening
# 3        Lambo              Zerg                     Hatch First
# 4         Cure            Terran                             NaN
#
#    player_1_winner_status player_1_league player_2_name player_2_species  \
# 0                       1             NaN      Couguar           Protoss
# 1                       0     Grandmaster       MaxPax           Protoss
# 2                       0             NaN      DKZDark              Zerg
# 3                       0             NaN       Serral              Zerg
# 4                       0             NaN       MaxPax           Protoss
#
#        player_2_build_order_names  player_2_winner_status player_2_league  \
# 0    1 Gate Expand, Colossus Rush                     0.0             NaN
# 1   1 Gate Expand, Blink Stalkers                     1.0     Grandmaster
# 2                     Hatch First                     1.0             NaN
# 3                     Hatch First                     1.0             NaN
# 4  1 Gate Expand, Phoenix Opening                     1.0          Master
#
#                       map     played_on_date_and_time game_length  \
# 0          Map: Hecate LE   Nov. 12, 2023, 11:16 a.m.       14:13
# 1         Map: Solaris LE    Oct. 30, 2023, 3:43 p.m.        9:39
# 2  Map: [ESL] NeoHumanity    May 20, 2023, 12:10 a.m.        7:31
# 3  Map: [ESL] NeoHumanity    Sept. 6, 2023, 6:34 a.m.        7:08
# 4         Map: Solaris LE    Oct. 18, 2023, 9:32 a.m.       11:35
#
#   tournament_name
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN

# %%
len(df_cleaned[False == df_cleaned['tournament_name'].isna()])/len(df_cleaned)
# Out:
# 0.8982

# %%
len(df_cleaned[False == df_cleaned['player_1_league'].isna()])/len(df_cleaned)
# Out:
# 0.1442

# %%
len(df_cleaned[False == df_cleaned['player_2_league'].isna()])/len(df_cleaned)
# Out:
# 0.154

# %%
def custom_date_parse(x):
    
    custom_strings = {'noon' : '12:00 pm'};
    
    if type(x) == float:
        return(np.nan);
    
    else:
        try:
            for key in custom_strings:
                if key in x:
                    x = x.replace(key, custom_strings[key]);

            return parse(x);
        
        except:
            return(np.nan);

# %%
df_cleaned.loc[:, 'played_on_date_and_time'] = df_cleaned['played_on_date_and_time'].apply(lambda x : custom_date_parse(x))

# %%
df_cleaned
# Out:
#      player_1_name player_1_species      player_1_build_order_names  \
# 0       Replicant            Terran                 Cyclone Opening
# 1          Spirit            Terran  Cyclone Opening, Reaper Expand
# 2         Classic           Protoss   1 Gate Expand, Oracle Opening
# 3           Lambo              Zerg                     Hatch First
# 4            Cure            Terran                             NaN
# ...            ...              ...                             ...
# 4995       wanted              Zerg                     Hatch First
# 4996       wanted              Zerg                     Hatch First
# 4997   iGCoffeeMs            Terran                   Reaper Expand
# 4998       wanted              Zerg            Hatch First, Lurkers
# 4999       wanted              Zerg                     Hatch First
#
#       player_1_winner_status player_1_league player_2_name player_2_species  \
# 0                          1             NaN      Couguar           Protoss
# 1                          0     Grandmaster       MaxPax           Protoss
# 2                          0             NaN      DKZDark              Zerg
# 3                          0             NaN       Serral              Zerg
# 4                          0             NaN       MaxPax           Protoss
# ...                      ...             ...           ...              ...
# 4995                       0             NaN   iGCoffeeMs            Terran
# 4996                       0             NaN   iGCoffeeMs            Terran
# 4997                       0             NaN       wanted              Zerg
# 4998                       0             NaN     iGMacSed           Protoss
# 4999                       0             NaN     iGMacSed           Protoss
#
#                    player_2_build_order_names  player_2_winner_status  \
# 0                1 Gate Expand, Colossus Rush                     0.0
# 1               1 Gate Expand, Blink Stalkers                     1.0
# 2                                 Hatch First                     1.0
# 3                                 Hatch First                     1.0
# 4              1 Gate Expand, Phoenix Opening                     1.0
# ...                                       ...                     ...
# 4995                            Reaper Expand                     1.0
# 4996         Liberator Opening, Reaper Expand                     1.0
# 4997                               Pool First                     1.0
# 4998  1 Gate Expand, Oracle Opening, Carriers                     1.0
# 4999            1 Gate Expand, Oracle Opening                     1.0
#
#      player_2_league                     map played_on_date_and_time  \
# 0                NaN          Map: Hecate LE     2023-11-12 11:16:00
# 1        Grandmaster         Map: Solaris LE     2023-10-30 15:43:00
# 2                NaN  Map: [ESL] NeoHumanity     2023-05-20 00:10:00
# 3                NaN  Map: [ESL] NeoHumanity     2023-09-06 06:34:00
# 4             Master         Map: Solaris LE     2023-10-18 09:32:00
# ...              ...                     ...                     ...
# 4995             NaN           Map: 锈化山巅-天梯版     2021-10-07 07:54:00
# 4996             NaN           Map: 紫晶浪漫-天梯版     2021-10-07 07:38:00
# 4997             NaN         Map: 大气2000-天梯版     2021-10-07 07:25:00
# 4998             NaN           Map: 世界主宰-天梯版     2021-10-06 09:26:00
# 4999             NaN           Map: 锈化山巅-天梯版     2021-10-06 09:43:00
#
#      game_length                           tournament_name
# 0          14:13                                       NaN
# 1           9:39                                       NaN
# 2           7:31                                       NaN
# 3           7:08                                       NaN
# 4          11:35                                       NaN
# ...          ...                                       ...
# 4995       14:17  Event: DreamHack SC2 Masters 2021 Winter
# 4996       10:44  Event: DreamHack SC2 Masters 2021 Winter
# 4997       20:40  Event: DreamHack SC2 Masters 2021 Winter
# 4998       17:35  Event: DreamHack SC2 Masters 2021 Winter
# 4999       14:27  Event: DreamHack SC2 Masters 2021 Winter
#
# [5000 rows x 14 columns]

# %%
len(df_cleaned[False == df_cleaned['played_on_date_and_time'].isna()])/len(df_cleaned)
# Out:
# 0.9996

# %%
df_cleaned.drop(df_cleaned[df_cleaned['played_on_date_and_time'].isna() == True].index, inplace = True)

# %%
df_cleaned
# Out:
#      player_1_name player_1_species      player_1_build_order_names  \
# 0       Replicant            Terran                 Cyclone Opening
# 1          Spirit            Terran  Cyclone Opening, Reaper Expand
# 2         Classic           Protoss   1 Gate Expand, Oracle Opening
# 3           Lambo              Zerg                     Hatch First
# 4            Cure            Terran                             NaN
# ...            ...              ...                             ...
# 4995       wanted              Zerg                     Hatch First
# 4996       wanted              Zerg                     Hatch First
# 4997   iGCoffeeMs            Terran                   Reaper Expand
# 4998       wanted              Zerg            Hatch First, Lurkers
# 4999       wanted              Zerg                     Hatch First
#
#       player_1_winner_status player_1_league player_2_name player_2_species  \
# 0                          1             NaN      Couguar           Protoss
# 1                          0     Grandmaster       MaxPax           Protoss
# 2                          0             NaN      DKZDark              Zerg
# 3                          0             NaN       Serral              Zerg
# 4                          0             NaN       MaxPax           Protoss
# ...                      ...             ...           ...              ...
# 4995                       0             NaN   iGCoffeeMs            Terran
# 4996                       0             NaN   iGCoffeeMs            Terran
# 4997                       0             NaN       wanted              Zerg
# 4998                       0             NaN     iGMacSed           Protoss
# 4999                       0             NaN     iGMacSed           Protoss
#
#                    player_2_build_order_names  player_2_winner_status  \
# 0                1 Gate Expand, Colossus Rush                     0.0
# 1               1 Gate Expand, Blink Stalkers                     1.0
# 2                                 Hatch First                     1.0
# 3                                 Hatch First                     1.0
# 4              1 Gate Expand, Phoenix Opening                     1.0
# ...                                       ...                     ...
# 4995                            Reaper Expand                     1.0
# 4996         Liberator Opening, Reaper Expand                     1.0
# 4997                               Pool First                     1.0
# 4998  1 Gate Expand, Oracle Opening, Carriers                     1.0
# 4999            1 Gate Expand, Oracle Opening                     1.0
#
#      player_2_league                     map played_on_date_and_time  \
# 0                NaN          Map: Hecate LE     2023-11-12 11:16:00
# 1        Grandmaster         Map: Solaris LE     2023-10-30 15:43:00
# 2                NaN  Map: [ESL] NeoHumanity     2023-05-20 00:10:00
# 3                NaN  Map: [ESL] NeoHumanity     2023-09-06 06:34:00
# 4             Master         Map: Solaris LE     2023-10-18 09:32:00
# ...              ...                     ...                     ...
# 4995             NaN           Map: 锈化山巅-天梯版     2021-10-07 07:54:00
# 4996             NaN           Map: 紫晶浪漫-天梯版     2021-10-07 07:38:00
# 4997             NaN         Map: 大气2000-天梯版     2021-10-07 07:25:00
# 4998             NaN           Map: 世界主宰-天梯版     2021-10-06 09:26:00
# 4999             NaN           Map: 锈化山巅-天梯版     2021-10-06 09:43:00
#
#      game_length                           tournament_name
# 0          14:13                                       NaN
# 1           9:39                                       NaN
# 2           7:31                                       NaN
# 3           7:08                                       NaN
# 4          11:35                                       NaN
# ...          ...                                       ...
# 4995       14:17  Event: DreamHack SC2 Masters 2021 Winter
# 4996       10:44  Event: DreamHack SC2 Masters 2021 Winter
# 4997       20:40  Event: DreamHack SC2 Masters 2021 Winter
# 4998       17:35  Event: DreamHack SC2 Masters 2021 Winter
# 4999       14:27  Event: DreamHack SC2 Masters 2021 Winter
#
# [4998 rows x 14 columns]

# %%
def custom_game_duration_format(x):
    y = x.strip();
    if len(y) == 1:
        z = x.replace(' ', '00:00:0');
    elif len(y) == 2:
        z = x.replace(' ', '00:00:');
    elif len(y) == 3:
        z = x.replace(' ', '00:00');
    elif len(y) == 4:
        z = x.replace(' ', '00:0');
    elif len(y) == 5:
        z = x.replace(' ', '00:');
    elif len(y) == 6:
        z = x.replace(' ', '00');
    elif len(y) == 7:
        z = x.replace(' ', '0');
    else:
        pass;
    
    time = pd.to_timedelta(z);
    time_minutes = time.total_seconds()/60
    
    return round(10*time_minutes)/10;

# %%
df_cleaned.loc[:, 'game_length'] = df_cleaned['game_length'].apply(lambda x : custom_game_duration_format(x))

# %%
df_cleaned = df_cleaned.rename(columns = {'game_length' : 'game_length_in_minutes'})

# %%
df_cleaned
# Out:
#      player_1_name player_1_species      player_1_build_order_names  \
# 0       Replicant            Terran                 Cyclone Opening
# 1          Spirit            Terran  Cyclone Opening, Reaper Expand
# 2         Classic           Protoss   1 Gate Expand, Oracle Opening
# 3           Lambo              Zerg                     Hatch First
# 4            Cure            Terran                             NaN
# ...            ...              ...                             ...
# 4995       wanted              Zerg                     Hatch First
# 4996       wanted              Zerg                     Hatch First
# 4997   iGCoffeeMs            Terran                   Reaper Expand
# 4998       wanted              Zerg            Hatch First, Lurkers
# 4999       wanted              Zerg                     Hatch First
#
#       player_1_winner_status player_1_league player_2_name player_2_species  \
# 0                          1             NaN      Couguar           Protoss
# 1                          0     Grandmaster       MaxPax           Protoss
# 2                          0             NaN      DKZDark              Zerg
# 3                          0             NaN       Serral              Zerg
# 4                          0             NaN       MaxPax           Protoss
# ...                      ...             ...           ...              ...
# 4995                       0             NaN   iGCoffeeMs            Terran
# 4996                       0             NaN   iGCoffeeMs            Terran
# 4997                       0             NaN       wanted              Zerg
# 4998                       0             NaN     iGMacSed           Protoss
# 4999                       0             NaN     iGMacSed           Protoss
#
#                    player_2_build_order_names  player_2_winner_status  \
# 0                1 Gate Expand, Colossus Rush                     0.0
# 1               1 Gate Expand, Blink Stalkers                     1.0
# 2                                 Hatch First                     1.0
# 3                                 Hatch First                     1.0
# 4              1 Gate Expand, Phoenix Opening                     1.0
# ...                                       ...                     ...
# 4995                            Reaper Expand                     1.0
# 4996         Liberator Opening, Reaper Expand                     1.0
# 4997                               Pool First                     1.0
# 4998  1 Gate Expand, Oracle Opening, Carriers                     1.0
# 4999            1 Gate Expand, Oracle Opening                     1.0
#
#      player_2_league                     map played_on_date_and_time  \
# 0                NaN          Map: Hecate LE     2023-11-12 11:16:00
# 1        Grandmaster         Map: Solaris LE     2023-10-30 15:43:00
# 2                NaN  Map: [ESL] NeoHumanity     2023-05-20 00:10:00
# 3                NaN  Map: [ESL] NeoHumanity     2023-09-06 06:34:00
# 4             Master         Map: Solaris LE     2023-10-18 09:32:00
# ...              ...                     ...                     ...
# 4995             NaN           Map: 锈化山巅-天梯版     2021-10-07 07:54:00
# 4996             NaN           Map: 紫晶浪漫-天梯版     2021-10-07 07:38:00
# 4997             NaN         Map: 大气2000-天梯版     2021-10-07 07:25:00
# 4998             NaN           Map: 世界主宰-天梯版     2021-10-06 09:26:00
# 4999             NaN           Map: 锈化山巅-天梯版     2021-10-06 09:43:00
#
#      game_length_in_minutes                           tournament_name
# 0                      14.2                                       NaN
# 1                       9.6                                       NaN
# 2                       7.5                                       NaN
# 3                       7.1                                       NaN
# 4                      11.6                                       NaN
# ...                     ...                                       ...
# 4995                   14.3  Event: DreamHack SC2 Masters 2021 Winter
# 4996                   10.7  Event: DreamHack SC2 Masters 2021 Winter
# 4997                   20.7  Event: DreamHack SC2 Masters 2021 Winter
# 4998                   17.6  Event: DreamHack SC2 Masters 2021 Winter
# 4999                   14.4  Event: DreamHack SC2 Masters 2021 Winter
#
# [4998 rows x 14 columns]

# %%
df_cleaned['player_2_winner_status'] = df_cleaned['player_2_winner_status'].apply(lambda x : int(x))

# %%
df_cleaned

# %%
df_cleanedi.iloc[0:1000, : ].to_csv('./esports-starcraft2-dashboard-data.csv')
